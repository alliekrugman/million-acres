# %%
#import pandas
import pandas as pd

# %%
#import xlsx
df = pd.read_excel('calenviroscreen.xlsx')
df
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6019001100              2780           Fresno   93706
# 1       6077000700              4680       San Joaquin  95206
# 2       6037204920              2751       Los Angeles  90023
# 3       6019000700              3664           Fresno   93706
# 4       6019000200              2689           Fresno   93706
# ...            ...               ...               ...    ...
# 8030    6107004000               582           Tulare   93257
# 8031    6109985202              2509         Tuolumne   95327
# 8032    6111001206               778          Ventura   93001
# 8033    6111003012               675          Ventura   93036
# 8034    6111980000               118          Ventura      61
#
#                      Approximate Location   Longitude   Latitude  \
# 0                                  Fresno -119.781696  36.709695
# 1                                Stockton -121.287873  37.943173
# ...

# %%
#isolate border counties
border_counties = df.loc[(df['California County'] == 'San Diego') | (df['California County'] == 'Imperial ')]
border_counties
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 156     6073003601              3006         San Diego  92113
# 253     6073005000              2195         San Diego  92113
# 295     6073004900              5505         San Diego  92113
# 315     6025012100              6779         Imperial   92231
# 321     6073003902              4388         San Diego  92113
# ...            ...               ...               ...    ...
# 8012    6073006200                23         San Diego  92101
# 8013    6073006300              3760         San Diego  92140
# 8014    6073009901               767         San Diego  92106
# 8015    6073009902                 0         San Diego  92118
# 8016    6073011300              2467         San Diego  92135
#
#      Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 156             San Diego -117.116515  32.690986      65.805306
# 253             San Diego -117.141175  32.694850      62.508922
# ...

# %%
df.dropna(subset=['PM2.5'], inplace=True)

# %%
border_counties.to_csv("border_counties.csv", index=False)
